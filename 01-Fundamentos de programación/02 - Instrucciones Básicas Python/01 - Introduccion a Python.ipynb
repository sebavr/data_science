# %% [markdown]
# # Introducción a Python
# - Operaciones aritméticas
# - Variables
# - Cadenas de Caracteres
# - Tipo booleano
# - Operadores de Comparación
# - Sentencias Condicionales

# %% [markdown]
# ## 1. Operaciones Aritméticas

# %%
2 + 2
# Out:
# 4

# %%
1 * 3
# Out:
# 3

# %%
2 - 1
# Out:
# 1

# %%
1 / 2
# Out:
# 0.5

# %%
# operacion modulo
7 % 2
# Out:
# 1

# %%
# precedencia (PEMDAS)
# 1. parentesis
# 2. Exponenciales (potencias y raices)
# 3. mult y div
# 4. sumas y restas
(2 + 3) * (5 + 5)
# Out:
# 50

# %% [markdown]
# ## 2. Variables

# %%
# debe partir con una letra
# el nombre puede contener numeros
# tambien algunos caracteres (_-)
# convención usar variables en minusculas
x = 2
y = 3

# %%
x + y
# Out:
# 5

# %%
x = 4

# %%
z = 2*x + y

# %%
z
# Out:
# 11

# %%
# Python es Case Sensitive
Z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b4379bcb7951> in <cell line: 1>()
# ----> 1 Z
#
# NameError: name 'Z' is not defined

# %%
type(x)
# Out:
# int

# %%
x = 3.14

# %%
type(x)
# Out:
# float

# %% [markdown]
# ## 3. Cadenas de caracteres

# %%
'hola mundo!'
# Out:
# 'hola mundo!'

# %%
"hola mundo!"
# Out:
# 'hola mundo!'

# %%
"Bernardo O'Higgins"
# Out:
# "Bernardo O'Higgins"

# %%
nombre = 'Miguel'

# %%
nombre
# Out:
# 'Miguel'

# %%
print(nombre)
# Out:
# Miguel

# %%
edad = 35

# %%
print('hola me llamo ' + nombre)
# Out:
# hola me llamo Miguel

# %%
# para los newbies...
print('tengo ' + str(edad) + ' años')
# Out:
# tengo 35 años

# %%
type(str(edad))
# Out:
# str

# %%
# placeholders {}
saludo = 'Me llamo {} y tengo {} años'

# %%
print(  saludo.format(nombre, edad)  )
# Out:
# Me llamo Miguel y tengo 35 años

# %%
# F-string  (para los pro...)
print( f'Me llamo {nombre} y tengo {edad} años' )
# Out:
# Me llamo Miguel y tengo 35 años

# %% [markdown]
# ## 4. Tipo Booleano

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
es_fumador = False

# %%
type(es_fumador)
# Out:
# bool

# %%
es_fumador
# Out:
# False

# %% [markdown]
# ## 5. Operadores de Comparación

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 2
# Out:
# False

# %%
1 <= 2
# Out:
# True

# %%
# operador de asignación 
a = 1
b = 2

# %%
# operador de igualdad
a == b
# Out:
# False

# %%
a = b

# %%
a == b
# Out:
# True

# %%
# operador "distinto que"
a != b
# Out:
# False

# %%
# operador de conjuncion
( a == b ) and (b > 1)
# Out:
# True

# %%
# operador de disjunción
( a == b) or (b > 1)
# Out:
# True

# %% [markdown]
# ## 6. Sentencias Condicionales

# %%
edad = 16

# %%
if edad >= 18:
  print('Puede pasar')
  print('QUe le vaya bien')

# %%
if edad >= 18:
  print('Puede pasar')
else:
  print('No puede pasar')
# Out:
# No puede pasar

# %%
if (edad >= 18) and (edad < 30):
  print('Joven')
elif (edad >= 30) and (edad < 40):
  print('Adulto Joven')
elif (edad >= 40) and (edad < 60):
  print('Adulto')
elif edad >= 60:
  print('Adulto Mayor')
else:
  print('Menor de Edad!!')
# Out:
# Menor de Edad!!

# %% [markdown]
# # Funciones
# - Funciones preconstruidas
# - Libreria Math
# - Funciones personalizadas

# %% [markdown]
# ## 7. Funciones Preconstruidas

# %%
s = 'Buenas Tardes!'
len(s) # largo en este caso de una cadena de caracteres
# Out:
# 14

# %%
n = -1.567
round(n) # redondeo
# Out:
# -2

# %%
round(n,1) # redondeo con 1 decimal
# Out:
# -1.6

# %%
abs(n) # valor absoluto
# Out:
# 1.567

# %% [markdown]
# ## 8. Librería Math

# %%
import math

# %%
math.cos( 2 * math.pi )
# Out:
# 1.0

# %%
math.log(10)
# Out:
# 2.302585092994046
