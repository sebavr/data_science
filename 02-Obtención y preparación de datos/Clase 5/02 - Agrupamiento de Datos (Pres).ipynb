# %% [markdown]
# ---
# # Agrupamiento de Datos
#
# En este notebook aprenderemos:
#
# - Multi-Indices
# - Función groupby()
# - Pivoteo de tablas
# - Despivoteo de tablas
#
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Multi-Índices

# %%
df = pd.read_csv('state-expenses.csv')
df
# Out:
#          State  Year  Expenses
# 0   California  2010  37253956
# 1     New York  2010  19378102
# 2     New York  2000  18976457
# 3        Texas  2000  20851820
# 4   California  2000  29483772
# 5      Chicago  2010  34888922
# 6  Los Angeles  2010  24877673
# 7        Texas  2010  23098724
# 8   California  2005  30477622

# %%
# setear indices en mas de un nivel en las filas
# ojo con inplace
df.set_index(['Year','State'], inplace=True)
df
# Out:
#                   Expenses
# Year State
# 2010 California   37253956
#      New York     19378102
# 2000 New York     18976457
#      Texas        20851820
#      California   29483772
# 2010 Chicago      34888922
#      Los Angeles  24877673
#      Texas        23098724
# 2005 California   30477622

# %%
df.reset_index(inplace=True)

# %%
# setear indices en mas de un nivel en las filas
# ojo con inplace
df.set_index(['State', 'Year'], inplace=True)
df
# Out:
#                   Expenses
# State       Year
# California  2010  37253956
# New York    2010  19378102
#             2000  18976457
# Texas       2000  20851820
# California  2000  29483772
# Chicago     2010  34888922
# Los Angeles 2010  24877673
# Texas       2010  23098724
# California  2005  30477622

# %%
# ahora verifiquemos los indices que tiene el dataframe
df.index
# Out:
# MultiIndex([( 'California', 2010),
#             (   'New York', 2010),
#             (   'New York', 2000),
#             (      'Texas', 2000),
#             ( 'California', 2000),
#             (    'Chicago', 2010),
#             ('Los Angeles', 2010),
#             (      'Texas', 2010),
#             ( 'California', 2005)],
#            names=['State', 'Year'])

# %%
# Cambiemosle nombre a los indices
df.index.names = ['Estado','Año']
df
# Out:
#                   Expenses
# Estado      Año
# California  2010  37253956
# New York    2010  19378102
#             2000  18976457
# Texas       2000  20851820
# California  2000  29483772
# Chicago     2010  34888922
# Los Angeles 2010  24877673
# Texas       2010  23098724
# California  2005  30477622

# %%
# Reordenando los niveles de indices
df.swaplevel('Año','Estado')
# Out:
#                   Expenses
# Año  Estado
# 2010 California   37253956
#      New York     19378102
# 2000 New York     18976457
#      Texas        20851820
#      California   29483772
# 2010 Chicago      34888922
#      Los Angeles  24877673
#      Texas        23098724
# 2005 California   30477622

# %%
# Ordenando los niveles de indices
df.sort_index(level=1, ascending=True)
# Out:
#                   Expenses
# Estado      Año
# California  2000  29483772
# New York    2000  18976457
# Texas       2000  20851820
# California  2005  30477622
#             2010  37253956
# Chicago     2010  34888922
# Los Angeles 2010  24877673
# New York    2010  19378102
# Texas       2010  23098724

# %%
# Sumario de estadisticas por nivel
df.sum(level=1)
# Out:
#        Expenses
# Año
# 2010  139497377
# 2000   69312049
# 2005   30477622

# %%
df.sum(level='Año')
# Out:
#        Expenses
# Año
# 2010  139497377
# 2000   69312049
# 2005   30477622

# %%
df.sum(level='Estado')
# Out:
#              Expenses
# Estado
# California   97215350
# New York     38354559
# Texas        43950544
# Chicago      34888922
# Los Angeles  24877673

# %% [markdown]
# ## 2. Función groupby()

# %%
df = pd.read_csv('state-expenses.csv')
df
# Out:
#          State  Year  Expenses
# 0   California  2010  37253956
# 1     New York  2010  19378102
# 2     New York  2000  18976457
# 3        Texas  2000  20851820
# 4   California  2000  29483772
# 5      Chicago  2010  34888922
# 6  Los Angeles  2010  24877673
# 7        Texas  2010  23098724
# 8   California  2005  30477622

# %% [markdown]
# Primero, definimos una agrupación de acuerdo a un criterio:

# %%
byYear = df.groupby('Year')

# %%
type(byYear)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# Ahora, realizamos operaciones de agrupación

# %%
byYear.count()
# Out:
#       State  Expenses
# Year
# 2000      3         3
# 2005      1         1
# 2010      5         5

# %%
byYear.sum()
# Out:
#        Expenses
# Year
# 2000   69312049
# 2005   30477622
# 2010  139497377

# %% [markdown]
# Todo en un mismo paso

# %%
df.groupby('State').sum()
# Out:
#              Year  Expenses
# State
# California   6015  97215350
# Chicago      2010  34888922
# Los Angeles  2010  24877673
# New York     4010  38354559
# Texas        4010  43950544

# %% [markdown]
# **El resultado es un dataframe, por lo tanto se puede operar como tal**

# %%
res = df.groupby('State').sum()
type(res)
# Out:
# pandas.core.frame.DataFrame

# %%
res['Year']
# Out:
# State
# California     6015
# Chicago        2010
# Los Angeles    2010
# New York       4010
# Texas          4010
# Name: Year, dtype: int64

# %%
res.loc['Chicago']
# Out:
# Year            2010
# Expenses    34888922
# Name: Chicago, dtype: int64

# %% [markdown]
# **Otros métodos**

# %%
df.groupby('State').min()
# Out:
#              Year  Expenses
# State
# California   2000  29483772
# Chicago      2010  34888922
# Los Angeles  2010  24877673
# New York     2000  18976457
# Texas        2000  20851820

# %%
df.groupby('State').max()
# Out:
#              Year  Expenses
# State
# California   2010  37253956
# Chicago      2010  34888922
# Los Angeles  2010  24877673
# New York     2010  19378102
# Texas        2010  23098724

# %%
df.groupby('State').mean()
# Out:
#                Year      Expenses
# State
# California   2005.0  3.240512e+07
# Chicago      2010.0  3.488892e+07
# Los Angeles  2010.0  2.487767e+07
# New York     2005.0  1.917728e+07
# Texas        2005.0  2.197527e+07

# %%
df.groupby('State').std()
# Out:
#                  Year      Expenses
# State
# California   5.000000  4.228518e+06
# Chicago           NaN           NaN
# Los Angeles       NaN           NaN
# New York     7.071068  2.840059e+05
# Texas        7.071068  1.588801e+06

# %%
df.groupby('State').median()
# Out:
#                Year    Expenses
# State
# California   2005.0  30477622.0
# Chicago      2010.0  34888922.0
# Los Angeles  2010.0  24877673.0
# New York     2005.0  19177279.5
# Texas        2005.0  21975272.0

# %%
df.groupby('State').quantile(q=0.5)
# Out:
#                Year    Expenses
# State
# California   2005.0  30477622.0
# Chicago      2010.0  34888922.0
# Los Angeles  2010.0  24877673.0
# New York     2005.0  19177279.5
# Texas        2005.0  21975272.0

# %% [markdown]
# **Descripción un dataframe agrupado**

# %%
df.groupby('State').describe()
# Out:
#              Year                                                            \
#             count    mean       std     min     25%     50%     75%     max
# State
# California    3.0  2005.0  5.000000  2000.0  2002.5  2005.0  2007.5  2010.0
# Chicago       1.0  2010.0       NaN  2010.0  2010.0  2010.0  2010.0  2010.0
# Los Angeles   1.0  2010.0       NaN  2010.0  2010.0  2010.0  2010.0  2010.0
# New York      2.0  2005.0  7.071068  2000.0  2002.5  2005.0  2007.5  2010.0
# Texas         2.0  2005.0  7.071068  2000.0  2002.5  2005.0  2007.5  2010.0
#
#             Expenses                                                       \
#                count          mean           std         min          25%
# State
# California       3.0  3.240512e+07  4.228518e+06  29483772.0  29980697.00
# Chicago          1.0  3.488892e+07           NaN  34888922.0  34888922.00
# Los Angeles      1.0  2.487767e+07           NaN  24877673.0  24877673.00
# New York         2.0  1.917728e+07  2.840059e+05  18976457.0  19076868.25
# Texas            2.0  2.197527e+07  1.588801e+06  20851820.0  21413546.00
#
#
#                     50%          75%         max
# State
# California   30477622.0  33865789.00  37253956.0
# Chicago      34888922.0  34888922.00  34888922.0
# Los Angeles  24877673.0  24877673.00  24877673.0
# New York     19177279.5  19277690.75  19378102.0
# Texas        21975272.0  22536998.00  23098724.0

# %% [markdown]
# **Agrupamiento por más de un criterio**

# %%
df.groupby(['State','Year']).sum()
# Out:
#                   Expenses
# State       Year
# California  2000  29483772
#             2005  30477622
#             2010  37253956
# Chicago     2010  34888922
# Los Angeles 2010  24877673
# New York    2000  18976457
#             2010  19378102
# Texas       2000  20851820
#             2010  23098724

# %%
df.groupby(['Year','State']).sum()
# Out:
#                   Expenses
# Year State
# 2000 California   29483772
#      New York     18976457
#      Texas        20851820
# 2005 California   30477622
# 2010 California   37253956
#      Chicago      34888922
#      Los Angeles  24877673
#      New York     19378102
#      Texas        23098724

# %% [markdown]
# ## 3. Pivoteo de tablas

# %%
df = pd.read_csv('state-expenses.csv')
# incorporamos una variable adicional al dataset
df['Investment'] = np.random.randint(1e7,9e7,9)
df
# Out:
#          State  Year  Expenses  Investment
# 0   California  2010  37253956    10778591
# 1     New York  2010  19378102    60824702
# 2     New York  2000  18976457    49477721
# 3        Texas  2000  20851820    36604653
# 4   California  2000  29483772    61432718
# 5      Chicago  2010  34888922    70699986
# 6  Los Angeles  2010  24877673    55260190
# 7        Texas  2010  23098724    63629831
# 8   California  2005  30477622    34859841

# %%
# Puede aplicarse funciones de agregación tales como sum, count, mean, min, max
df.pivot_table(values='Expenses', index='State', columns='Year', aggfunc='sum', fill_value=0)
# Out:
# Year             2000      2005      2010
# State
# California   29483772  30477622  37253956
# Chicago             0         0  34888922
# Los Angeles         0         0  24877673
# New York     18976457         0  19378102
# Texas        20851820         0  23098724

# %%
df.pivot_table(values=['Expenses','Investment'], index='State', columns='Year', aggfunc='sum', fill_value=0)
# Out:
#              Expenses                     Investment
# Year             2000      2005      2010       2000      2005      2010
# State
# California   29483772  30477622  37253956   61432718  34859841  10778591
# Chicago             0         0  34888922          0         0  70699986
# Los Angeles         0         0  24877673          0         0  55260190
# New York     18976457         0  19378102   49477721         0  60824702
# Texas        20851820         0  23098724   36604653         0  63629831

# %% [markdown]
# Si no se especifican columnas, entonces el reporte es similar a uno de agrupación (groupby)

# %%
df.pivot_table(values=['Expenses','Investment'], index=['State','Year'], aggfunc='sum', fill_value=0)
# Out:
#                   Expenses  Investment
# State       Year
# California  2000  29483772    61432718
#             2005  30477622    34859841
#             2010  37253956    10778591
# Chicago     2010  34888922    70699986
# Los Angeles 2010  24877673    55260190
# New York    2000  18976457    49477721
#             2010  19378102    60824702
# Texas       2000  20851820    36604653
#             2010  23098724    63629831

# %% [markdown]
# ## 4. Despivoteo de tablas

# %% [markdown]
# Vamos a extraer desde EIA (US Energy Information Administration) la data del precio del gas natural (mes y año)

# %%
url = 'https://www.eia.gov/dnav/ng/hist/rngwhhdM.htm'
tables = pd.read_html(url)

# %%
# Explorando, la tabla 4 es la que tiene la información requerida
df = tables[4].copy()

# %%
df.head()
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1997.0  3.45  2.15  1.89  2.03  2.25  2.20  2.19  2.49  2.88  3.07  3.01
# 1  1998.0  2.09  2.23  2.24  2.43  2.14  2.17  2.17  1.85  2.02  1.91  2.12
# 2  1999.0  1.85  1.77  1.79  2.15  2.26  2.30  2.31  2.80  2.55  2.73  2.37
# 3     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2000.0  2.42  2.66  2.79  3.04  3.59  4.29  3.99  4.43  5.06  5.02  5.52
#
#     Dec
# 0  2.35
# 1  1.72
# 2  2.36
# 3   NaN
# 4  8.90

# %% [markdown]
# Al parecer, hay lineas en blanco (espaciadoras), entonces removemos las filas con más de 10 espacios en blanco

# %%
df.dropna(thresh=10,inplace=True)

# %% [markdown]
# Cambiamos el tipo de dato del año a *int*, ya que fue reconocido como *float* al cargar la data

# %%
df['Year'] = df['Year'].astype(int)

# %%
df
# Out:
#     Year   Jan   Feb   Mar    Apr    May    Jun    Jul   Aug    Sep    Oct  \
# 0   1997  3.45  2.15  1.89   2.03   2.25   2.20   2.19  2.49   2.88   3.07
# 1   1998  2.09  2.23  2.24   2.43   2.14   2.17   2.17  1.85   2.02   1.91
# 2   1999  1.85  1.77  1.79   2.15   2.26   2.30   2.31  2.80   2.55   2.73
# 4   2000  2.42  2.66  2.79   3.04   3.59   4.29   3.99  4.43   5.06   5.02
# 5   2001  8.17  5.61  5.23   5.19   4.19   3.72   3.11  2.97   2.19   2.46
# 6   2002  2.32  2.32  3.03   3.43   3.50   3.26   2.99  3.09   3.55   4.13
# 7   2003  5.43  7.71  5.93   5.26   5.81   5.82   5.03  4.99   4.62   4.63
# 8   2004  6.14  5.37  5.39   5.71   6.33   6.27   5.93  5.41   5.15   6.35
# 10  2005  6.15  6.14  6.96   7.16   6.47   7.18   7.63  9.53  11.75  13.42
# 11  2006  8.69  7.54  6.89   7.16   6.25   6.21   6.17  7.14   4.90   5.85
# 12  2007  6.55  8.00  7.11   7.60   7.64   7.35   6.22  6.22   6.08   6.74
# 13  2008  7.99  8.54  9.41  10.18  11.27  12.69  11.09  8.26   7.67   6.74
# 14  2009  5.24  4.52  3.96   3.50   3.83   3.80   3.38  3.14   2.99   4.01
# 16  2010  5.83  5.32  4.29   4.03   4.14   4.80   4.63  4.32   3.89   3.43
# 17  2011  4.49  4.09  3.97   4.24   4.31   4.54   4.42  4.06   3.90   3.57
# 18  2012  2.67  2.51  2.17   1.95   2.43   2.46   2.95  2.84   2.85   3.32
# 19  2013  3.33  3.33  3.81   4.17   4.04   3.83   3.62  3.43   3.62   3.68
# 20  2014  4.71  6.00  4.90   4.66   4.58   4.59   4.05  3.91   3.92   3.78
# 22  2015  2.99  2.87  2.83   2.61   2.85   2.78   2.84  2.77   2.66   2.34
# 23  2016  2.28  1.99  1.73   1.92   1.92   2.59   2.82  2.82   2.99   2.98
# 24  2017  3.30  2.85  2.88   3.10   3.15   2.98   2.98  2.90   2.98   2.88
# 25  2018  3.87  2.67  2.69   2.80   2.80   2.97   2.83  2.96   3.00   3.28
# 26  2019  3.11  2.69  2.95   2.65   2.64   2.40   2.37  2.22   2.56   2.33
#
#       Nov    Dec
# 0    3.01   2.35
# 1    2.12   1.72
# 2    2.37   2.36
# 4    5.52   8.90
# 5    2.34   2.30
# 6    4.04   4.74
# 7    4.47   6.13
# 8    6.17   6.58
# 10  10.30  13.05
# 11   7.41   6.73
# 12   7.10   7.11
# 13   6.68   5.82
# 14   3.66   5.35
# 16   3.71   4.25
# 17   3.24   3.17
# 18   3.54   3.34
# 19   3.64   4.24
# 20   4.12   3.48
# 22   2.09   1.93
# 23   2.55   3.59
# 24   3.01   2.82
# 25   4.09   4.04
# 26   2.65   2.22

# %% [markdown]
# Ahora que el set de datos está depurado, vamos a despivotear la tabla

# %%
df.melt(id_vars='Year', var_name='Month', value_name='Precio')
# Out:
#      Year Month  Precio
# 0    1997   Jan    3.45
# 1    1998   Jan    2.09
# 2    1999   Jan    1.85
# 3    2000   Jan    2.42
# 4    2001   Jan    8.17
# ..    ...   ...     ...
# 271  2015   Dec    1.93
# 272  2016   Dec    3.59
# 273  2017   Dec    2.82
# 274  2018   Dec    4.04
# 275  2019   Dec    2.22
#
# [276 rows x 3 columns]

# %% [markdown]
# ---
