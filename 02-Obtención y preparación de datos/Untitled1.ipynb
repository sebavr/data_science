# %% [markdown]
# # Consolidado

# %%
import pandas as pd

# %%
a=pd.read_csv('Trabajo-final-Deposito.csv',encoding='latin-1')
b=pd.read_csv('Trabajo-final-Colocaciones.csv',encoding='latin-1')
c=pd.read_csv('Trabajo-final-Inversiones.csv',encoding='latin-1')

# %%
ab=pd.merge(a,b , left_on='InstituciÃ³n Financiera', right_on='InstituciÃ³n Financiera' )

# %%
ab
# Out:
#           Unnamed: 0_x   Fecha InstituciÃ³n Financiera_x     Tipo_x  \
# 0                    0  1-2008  Banco BTG Pactual Chile   DepÃ³sito
# 1                    0  1-2008  Banco BTG Pactual Chile   DepÃ³sito
# 2                    0  1-2008  Banco BTG Pactual Chile   DepÃ³sito
# 3                    0  1-2008  Banco BTG Pactual Chile   DepÃ³sito
# 4                    0  1-2008  Banco BTG Pactual Chile   DepÃ³sito
# ...                ...     ...                       ...        ...
# 10825645         40094  9-2021                     Total  DepÃ³sito
# 10825646         40094  9-2021                     Total  DepÃ³sito
# 10825647         40094  9-2021                     Total  DepÃ³sito
# 10825648         40094  9-2021                     Total  DepÃ³sito
# 10825649         40094  9-2021                     Total  DepÃ³sito
#
#                                                   Subtipo_x      Valor_x  \
# 0                                        DepÃ³sitos a plazo          0.0
# ...
