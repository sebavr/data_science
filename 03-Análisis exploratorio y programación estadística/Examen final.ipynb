# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('precios-propiedades.csv', encoding='windows-1252')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
df['ZN'].unique()
# Out:
# array([ 18. ,   0. ,  12.5,  75. ,  21. ,  90. ,  85. , 100. ,  25. ,
#         17.5,  80. ,  28. ,  45. ,  60. ,  95. ,  82.5,  30. ,  22. ,
#         20. ,  40. ,  55. ,  52.5,  70. ,  34. ,  33. ,  35. ])

# %%
df['RAD'].unique()
# Out:
# array([ 1.,  2.,  3.,  5.,  4.,  8.,  6.,  7., 24.])

# %%
df['TAX'].unique()
# Out:
# array([296., 242., 222., 311., 307., 279., 252., 233., 243., 469., 226.,
#        313., 256., 284., 216., 337., 345., 305., 398., 281., 247., 270.,
#        276., 384., 432., 188., 437., 403., 193., 265., 255., 329., 402.,
#        348., 224., 277., 300., 330., 315., 244., 264., 223., 254., 198.,
#        285., 241., 293., 245., 289., 358., 304., 287., 430., 422., 370.,
#        352., 351., 280., 335., 411., 187., 334., 666., 711., 391., 273.])

# %%
df['PTRATIO'].unique()
# Out:
# array([15.3, 17.8, 18.7, 15.2, 21. , 19.2, 18.3, 17.9, 16.8, 21.1, 17.3,
#        15.1, 19.7, 18.6, 16.1, 18.9, 19. , 18.5, 18.2, 18. , 20.9, 19.1,
#        21.2, 14.7, 16.6, 15.6, 14.4, 12.6, 17. , 16.4, 17.4, 15.9, 13. ,
#        17.6, 14.9, 13.6, 16. , 14.8, 18.4, 19.6, 16.9, 20.2, 15.5, 18.8,
#        22. , 20.1])

# %%
df['CRIM'].min()
# Out:
# 0.00632

# %% [markdown]
# ### Tipo de variable de cada atributo

# %% [markdown]
# - CRIM:Cuantitativa Continua
# - ZN: Cuantitativa Continua
# - INDUS:Cuantitativa Continua
# - CHAS:Cualitativa Nominal que para el problema debe de adaptarse a números enteros. Por lo que se considera Cuantitativa Discreta.
# - NOX:Cuantitativa Continua
# - RM:Cuantitativa Continua
# - AGE:Cuantitativa Continua
# - DIS:Cuantitativa Continua
# - RAD:Cuantitativa Discreta
# - TAX:Cuantitativa Discreta
# - PTRATIO:Cuantitativa Continua
# - B:Cuantitativa Continua
# - LSTAT:Cuantitativa Continua
# - MEDV:Cuantitativa Continua

# %% [markdown]
# ### Medidas de tendencia central y dispersión a utilizar

# %% [markdown]
# - Se utilizará Media,Mediana,Moda, Desviación estándar. Esto junto a visualizaciones para comprender mejor el comportamiento de los valores.
#
# - La variable CHAS es originalmente una variable Cualitativa Nominal que tuvo que transformarse a numeros enteros para poder realizar calculos y operaciones con ella. Sin embargo se hará una analisis para ver si de verdad es factible esta variable.

# %% [markdown]
# ### Analisis Exploratorio

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# MEDV       229
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ### Analisis variable CHAS

# %%
df['CHAS'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['CHAS'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['CHAS2']=df['CHAS']
t=[]

for i in range(0,df['CHAS2'].shape[0]):
    if s[i]==0:
        t.append('Limita')
    else:
        t.append('No limita')
print(t)

df['CHAS2']=t
df
# Out:
# ['Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita', 'Limita
# ...

# %% [markdown]
# ### Analisis limite con el rio y valor de propiedad

# %%
sns.barplot(x='CHAS2', y='MEDV', data=df)
# Out:
# <Axes: xlabel='CHAS2', ylabel='MEDV'>

# %%
p=df.pivot_table(index='CHAS2', values='MEDV', aggfunc='sum')
p
# Out:
#               MEDV
# CHAS2
# Limita     10406.2
# No limita    995.4

# %%
df['MEDV'].sum()
# Out:
# 11401.600000000002

# %% [markdown]
# La variable CHAS se transformo para poder hacer analisis con graficos categoricos con ella.

# %% [markdown]
# ### Analisis variable CRIM

# %%
q1 = df['CRIM'].quantile(q=.2)
q2 = df['CRIM'].quantile(q=.4)
q3 = df['CRIM'].quantile(q=.6)
q4 = df['CRIM'].quantile(q=.8)

print('Q1:',q1)
print('Q2:',q2)
print('Q3:',q3)
print('Q1:',q4)
# Out:
# Q1: 0.06417
# Q2: 0.15038
# Q3: 0.55007
# Q1: 5.58107

# %%
df['CRIM'].plot(kind='hist', bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['CRIM'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Se observa que hay una serie de valores atipicos para la variable CRIM. Estas se eliminaran del modelo.

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['CRIM'], df['MEDV'])
 
# x-axis label
ax.set_xlabel('Tasa de criminalidad per cápita del secto')
 
# y-axis label
ax.set_ylabel('Valor de las viviendas')
plt.show()

# %%
atipicos=df[df['CRIM']>10].index
df.drop(atipicos,inplace = True)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df['CRIM'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Analisis variable ZN

# %%
df['ZN'].plot(kind='hist', bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
Al igual que CRIM, esta variable presenta muchos datos que rondan el valor 0.

# %%
sns.pairplot(df)

# %% [markdown]
# Se aprecia mejor lo que se comentaba anteriormente. Dadas las correlaciones se pueden ver que muchas  mantienen valores atipicos y además muestran signos de no homocedasticidad. Muchos datos se concentran en solo una frecuencia de datos.

# %%
fig= plt.figure(figsize=(20,20))
axe=fig.add_axes([0,0,1,1])
sns.heatmap(df.corr(), cmap='coolwarm',linewidths=1,linecolor='white',annot=True, fmt='f',ax=axe)
# Out:
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_9104\3134139988.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap='coolwarm',linewidths=1,linecolor='white',annot=True, fmt='f',ax=axe)
# <Axes: >

# %% [markdown]
# CRIM con RAD y TAX
# INDUS con DIS, TAX,NOX
# RM y MEDV
# AGE y NOX
# DIS y NOX
# TAX y CRIM,RAD
# MEDV y LSTAT

# %% [markdown]
# ### Formulación del módelo

# %%
import statsmodels.formula.api as smf
import statsmodels.tools.eval_measures as metrics

# %% [markdown]
# ### Modelo con todas las variables

# %%
lm = smf.ols(formula='''Q("MEDV") 
                            ~ Q("CRIM") + 
                              Q("ZN") + 
                              Q("INDUS") + 
                              Q("CHAS") +
                               Q("NOX") +
                                Q("RM") +
                                 Q("AGE") +
                                  Q("DIS") +
                                   Q("RAD") +
                                   Q("TAX") +
                                    Q("PTRATIO") +
                                    Q("B") +
                                    
                                    Q("LSTAT")  ''',data=df).fit()

# %%
lm.params
# Out:
# Intercept       36.459488
# Q("CRIM")       -0.108011
# Q("ZN")          0.046420
# Q("INDUS")       0.020559
# Q("CHAS")        2.686734
# Q("NOX")       -17.766611
# Q("RM")          3.809865
# Q("AGE")         0.000692
# Q("DIS")        -1.475567
# Q("RAD")         0.306049
# Q("TAX")        -0.012335
# Q("PTRATIO")    -0.952747
# Q("B")           0.009312
# Q("LSTAT")      -0.524758
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Q("MEDV")   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):          6.72e-135
# Time:                        19:47:22   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
y_true = df['MEDV']
y_pred = lm.predict(df[['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT']])




print( 'MAE: {}'.format(metrics.meanabs(y_true,y_pred)) ) 
print( 'MSE: {}'.format(metrics.mse(y_true,y_pred)) )
print( 'RMSE: {}'.format(metrics.rmse(y_true,y_pred)) )
print( 'R2: {}'.format(lm.rsquared))
print( 'R2-Adj: {}'.format(lm.rsquared_adj))
# Out:
# MAE: 3.270862810900312
# MSE: 21.894831181729206
# RMSE: 4.679191295697282
# R2: 0.7406426641094095
# R2-Adj: 0.733789726372463

# %%
plt.scatter(y_true,y_pred)
plt.xlabel('Y Real')
plt.ylabel('Predicción Y')
# Out:
# Text(0, 0.5, 'Predicción Y')

# %% [markdown]
# ### Ajuste del modelo

# %% [markdown]
# Según el análisis de altas correlaciones, se sacan algunas variables.
# Corresponderia sacar del modelo a INDUS,AGE. Probaremos con eso.
# Esto porque se tiene un nivel de ajuste de 0.05, por lo que las variables que sean mayores a ello, son elimnadas.

# %%
CRIM con RAD y TAX
INDUS con DIS, TAX,NOX
RM y MEDV
AGE y NOX
DIS y NOX
TAX y CRIM,RAD
MEDV y LSTAT

# %%
lm = smf.ols(formula='''Q("MEDV") 
                            ~ Q("CRIM") + 
                              Q("ZN") + 
                             
                              Q("CHAS") +
                               Q("NOX") +
                                Q("RM") +
                               
                                  Q("DIS") +
                                   Q("RAD") +
                                   Q("TAX") +
                                    Q("PTRATIO") +
                                    Q("B") +
                                    
                                    Q("LSTAT")  ''',data=df).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Q("MEDV")   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     128.2
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):          5.54e-137
# Time:                        19:47:48   Log-Likelihood:                -1498.9
# No. Observations:                 506   AIC:                             3022.
# Df Residuals:                     494   BIC:                             3072.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
y_true = df['MEDV']
y_pred = lm.predict(df[['CRIM','ZN','CHAS','NOX','RM','DIS','RAD','TAX','PTRATIO','B','LSTAT']])




print( 'MAE: {}'.format(metrics.meanabs(y_true,y_pred)) ) 
print( 'MSE: {}'.format(metrics.mse(y_true,y_pred)) )
print( 'RMSE: {}'.format(metrics.rmse(y_true,y_pred)) )
print( 'R2: {}'.format(lm.rsquared))
print( 'R2-Adj: {}'.format(lm.rsquared_adj))
# Out:
# MAE: 3.272036041027305
# MSE: 21.8999287597522
# RMSE: 4.679735971158223
# R2: 0.7405822802569575
# R2-Adj: 0.7348057723274566

# %%
plt.scatter(y_true,y_pred)
plt.xlabel('Y Real')
plt.ylabel('Predicción Y')
# Out:
# Text(0, 0.5, 'Predicción Y')

# %%
lm.params
# Out:
# Intercept       36.341145
# Q("CRIM")       -0.108413
# Q("ZN")          0.045845
# Q("CHAS")        2.718716
# Q("NOX")       -17.376023
# Q("RM")          3.801579
# Q("DIS")        -1.492711
# Q("RAD")         0.299608
# Q("TAX")        -0.011778
# Q("PTRATIO")    -0.946525
# Q("B")           0.009291
# Q("LSTAT")      -0.522553
# dtype: float64

# %%
### Conclusion
- Las variables que mas tienen incidencia en el modelo son NOX, RM y CHAS:
- Por cada unidad que se incrementa de NOX, el valor de la vivienda disminuye en 17370 US
- Por cada unidad que se incrementa de RM, el valor de la vivienda aumenta en 3801 US
- Por cada unidad que se incrementa de CHAS, el valor de la vivienda aumenta en  2710 US
