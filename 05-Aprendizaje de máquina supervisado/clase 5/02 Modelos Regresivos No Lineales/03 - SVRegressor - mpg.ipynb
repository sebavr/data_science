# %% [markdown]
# # Support Vector Regressor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('auto-mpg.csv')

# %%
df.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
plt.title('Millas por Galón de combustible')
sns.scatterplot(data=df, x='weight', y='mpg')
# Out:
# <AxesSubplot:title={'center':'Millas por Galón de combustible'}, xlabel='weight', ylabel='mpg'>

# %%
plt.title('Millas por Galón de combustible')
sns.regplot(data=df, x='weight', y='mpg')
# Out:
# <AxesSubplot:title={'center':'Millas por Galón de combustible'}, xlabel='weight', ylabel='mpg'>

# %%
plt.title('Millas por Galón de combustible')
sns.regplot(data=df, x='weight', y='mpg', order=2)
# Out:
# <AxesSubplot:title={'center':'Millas por Galón de combustible'}, xlabel='weight', ylabel='mpg'>

# %% [markdown]
# ## Modelo

# %%
X = df[['weight']]
y =df['mpg']

# %% [markdown]
# ## Support Cruzada

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=0)

# %% [markdown]
# ## Support Vector Regressor

# %%
from sklearn.svm import SVR

# %%
regressor = SVR(kernel = 'rbf')

# %%
regressor.fit(X_train, y_train)
# Out:
# SVR()

# %% [markdown]
# ## Evaluación

# %%
y_pred = regressor.predict(X_test)

# %%
regressor.score(X_test,y_test)
# Out:
# 0.7552113770548685

# %% [markdown]
# ## Visualización

# %%
X_plot = np.arange(1600,5500).reshape(-1,1)
X_plot
# Out:
# array([[1600],
#        [1601],
#        [1602],
#        ...,
#        [5497],
#        [5498],
#        [5499]])

# %%
plt.title('Millas por Galón de combustible')
plt.plot(X_plot, regressor.predict(X_plot), c='k', label='Modelo Polinomial')
sns.scatterplot(data=df, x='weight', y='mpg', label='Datos Reales')
plt.legend(loc=0)
# Out:
# c:\Users\jorge\miniconda3\envs\machinelearning\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
